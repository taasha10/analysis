# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("2010 Federal STEM Education Inventory Data Set.xls")

# %%
df.head()
# Out:
#                                                         PROGRAM  \
# Index Number                                    Investment Name
# PRG_0001      Centers for Ocean Sciences Education Excellence ~
# PRG_0002            Broadening Participation in Computing (BPC)
# PRG_0003      CISE Pathways to Revitalized Undergraduate Com...
# PRG_0004      Opportunities for Enhancing Diversity in the G...
#
#                                Unnamed: 1  \
# Index Number                       Agency
# PRG_0001      National Science Foundation
# PRG_0002      National Science Foundation
# PRG_0003      National Science Foundation
# PRG_0004      National Science Foundation
#
#                                                      Unnamed: 2  \
# Index Number                                          Subagency
# PRG_0001                      Directorate for Geosciences (GEO)
# PRG_0002      Directorate for Computer & Information Science...
# ...

# %%
df.describe()
# Out:
#        Unnamed: 162  Unnamed: 165  Unnamed: 168  Unnamed: 171  Unnamed: 177  \
# count     12.000000      4.000000        1.0000         1.000      2.000000
# mean       1.650048      1.048625        0.0445         0.089      0.887000
# std        1.910847      1.392363           NaN           NaN      1.112986
# min        0.050000      0.044500        0.0445         0.089      0.100000
# 25%        0.198375      0.048625        0.0445         0.089      0.493500
# 50%        0.737625      0.575000        0.0445         0.089      0.887000
# 75%        3.250457      1.575000        0.0445         0.089      1.280500
# max        5.000000      3.000000        0.0445         0.089      1.674000
#
#        Unnamed: 180  Unnamed: 183
# count          1.00         1.000
# mean           1.82         2.204
# std             NaN           NaN
# min            1.82         2.204
# 25%            1.82         2.204
# 50%            1.82         2.204
# 75%            1.82         2.204
# ...

# %%
df.reset_index(drop= True,inplace= True)
df
# Out:
#                                                PROGRAM  \
# 0                                      Investment Name
# 1    Centers for Ocean Sciences Education Excellence ~
# 2          Broadening Participation in Computing (BPC)
# 3    CISE Pathways to Revitalized Undergraduate Com...
# 4    Opportunities for Enhancing Diversity in the G...
# 5                                 Geoscience Education
# 6              Geoscience Teacher Training (GEO-Teach)
# 7    Global Learning and Observations to Benefit th...
# 8          Graduate Research Fellowship Program (GRFP)
# 9    Integrative Graduate Education and Research Tr...
# 10   Graduate Teaching Fellows in K-12 Education (G...
# 11   East Asia & Pacific Summer Institutes for U.S....
# 12   Undergraduate Research and Mentoring in the Bi...
# 13              Advanced Technological Education (ATE)
# 14     Transforming Undergrad Education in STEM (TUES)
# 15                      Climate Change Education (CCE)
# ...

# %%
df.dropna(inplace= True,subset = ['Unnamed: 5','Unnamed: 6'])

# %%
df
# Out:
#                                                PROGRAM  \
# 0                                      Investment Name
# 1    Centers for Ocean Sciences Education Excellence ~
# 2          Broadening Participation in Computing (BPC)
# 3    CISE Pathways to Revitalized Undergraduate Com...
# 4    Opportunities for Enhancing Diversity in the G...
# 5                                 Geoscience Education
# 6              Geoscience Teacher Training (GEO-Teach)
# 7    Global Learning and Observations to Benefit th...
# 8          Graduate Research Fellowship Program (GRFP)
# 9    Integrative Graduate Education and Research Tr...
# 10   Graduate Teaching Fellows in K-12 Education (G...
# 11   East Asia & Pacific Summer Institutes for U.S....
# 12   Undergraduate Research and Mentoring in the Bi...
# 13              Advanced Technological Education (ATE)
# 14     Transforming Undergrad Education in STEM (TUES)
# 15                      Climate Change Education (CCE)
# ...

# %% [markdown]
# # calculating % growth

# %%
def funding(fund):
    if fund > 0:
        fund = 1;
    else :
        fund = 0;
    return fund;

# %%
fund_1 = df[df['Unnamed: 5'] != 0].iloc[1:,5]
fund_2 = df[df['Unnamed: 5'] != 0].iloc[1:,6]
fund_diff = fund_2 - fund_1
growth_rate = fund_diff/fund_1 * 100;
growth_rate
# Out:
# 1       37.2137
# 2             0
# 3             0
# 4       157.987
# 5       68.0982
# 6             0
# 7       1.81818
# 8       69.1627
# 9       20.4293
# 10      7.76557
# 11     -13.1429
# 12     -8.05501
# 13      0.75787
# 14        9.603
# 16     -7.54039
# 17      30.8707
# 18      79.6323
# 19      60.3159
# 20      108.901
# 21     -1.32293
# 22      5.67686
# 23      55.7196
# 24      38.4892
# 25      16.8103
# 26      9.22922
# 27      2.25636
# 28      1.97052
# 29      85.1852
# 30      45.8438
# 31      99.1304
#          ...
# 221         100
# 222     4.24082
# 223     24.1689
# 224           0
# 225     103.213
# 226     9.08621
# 227     3.57143
# 228    -53.2075
# 229     22.7941
# 230     41.0579
# 232     12.1087
# 233     1.42784
# 234     1.43627
# 235    0.934579
# 236     6.81818
# 237        41.8
# 238      32.414
# 239     41.9108
# 241    -28.5714
# 242           0
# 243          60
# 244     26.5537
# 245     25.6831
# 246    -2.99443
# ...

# %%
total = growth_rate.sum()/217
total
# Out:
# 31.74102016254766

# %%
df['growth_rate'] = growth_rate.apply(funding)

# %%
df
# Out:
#                                                PROGRAM  \
# 0                                      Investment Name
# 1    Centers for Ocean Sciences Education Excellence ~
# 2          Broadening Participation in Computing (BPC)
# 3    CISE Pathways to Revitalized Undergraduate Com...
# 4    Opportunities for Enhancing Diversity in the G...
# 5                                 Geoscience Education
# 6              Geoscience Teacher Training (GEO-Teach)
# 7    Global Learning and Observations to Benefit th...
# 8          Graduate Research Fellowship Program (GRFP)
# 9    Integrative Graduate Education and Research Tr...
# 10   Graduate Teaching Fellows in K-12 Education (G...
# 11   East Asia & Pacific Summer Institutes for U.S....
# 12   Undergraduate Research and Mentoring in the Bi...
# 13              Advanced Technological Education (ATE)
# 14     Transforming Undergrad Education in STEM (TUES)
# 15                      Climate Change Education (CCE)
# ...

# %%
df.dropna(inplace=True,subset = ['growth_rate'])

# %% [markdown]
# # stage 2

# %%
df.columns
# Out:
# Index(['PROGRAM', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'FUNDING',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248', 'Unnamed: 249',
#        'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252', 'Unnamed: 253',
#        'Unnamed: 254', 'growth_rate'],
#       dtype='object', length=256)

# %%
import matplotlib.pyplot as plt

# %%
df['Unnamed: 1'].value_counts().plot.bar()

# %%
df['Unnamed: 2'].value_counts().head(10).plot.bar()

# %%
df['FUNDING'].value_counts().head(15).plot.bar()

# %%
df['Unnamed: 8'].value_counts().plot.bar()
